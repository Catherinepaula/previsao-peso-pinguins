# %%
# 🐧 Projeto M24 – Classificação de Espécie de Pinguins

Este notebook faz parte do curso de Análise de Dados da EBAC (Módulo 24) e tem como objetivo **prever a espécie** de um pinguim a partir de suas características físicas e geográficas, usando um **Árvore de Decisão**.

# %%
# === 1. Importação de bibliotecas ===
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# Para deixar os gráficos maiores no Colab
plt.rcParams["figure.figsize"] = (8,6)
sns.set_style("whitegrid")

# %%
# === 1. Importação de bibliotecas ===
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# Para deixar os gráficos maiores no Colab
plt.rcParams["figure.figsize"] = (8,6)
sns.set_style("whitegrid")

# %%
# === 2. Carregamento da base de dados ===
df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## 1. Análise Exploratória
#
# Vamos entender as relações entre variáveis preditivas e a variável resposta (`species`).
#
# **Gráficos solicitados:**
# 1. Atributos numéricos por espécie
# 2. Sexo por espécie
# 3. Ilha por espécie

# %%
# 1.1 Atributos numéricos por espécie
# Usamos pairplot limitado a duas variáveis exemplares para não sobrecarregar.
sns.pairplot(df, vars=["bill_length_mm","flipper_length_mm"], hue="species", height=3)
plt.suptitle("Comprimento do bico e nadadeira por Espécie", y=1.02);

# %% [markdown]
# **Comentário:**
# - Percebe‑se que Gentoo (laranja) tende a ter **nadadeiras mais longas** e bicos maiores.
# - Adelie (azul) e Chinstrap (verde) ocupam regiões distintas no gráfico.
# Isso sugere que esses atributos são fortes discriminadores de espécie.

# %%
# 1.2 Sexo por espécie
sns.countplot(data=df, x="sex", hue="species")
plt.title("Distribuição de Sexo por Espécie");

# %% [markdown]
# **Comentário:**
# - Observa‑se que há mais indivíduos machos em Gentoo e Chinstrap.
# - O desbalanceamento de sexo pode influenciar o modelo, mas aqui usamos apenas como insight exploratório.

# %%
# 1.3 Ilha por espécie
sns.countplot(data=df, x="island", hue="species")
plt.title("Distribuição de Espécie por Ilha");

# %% [markdown]
# **Comentário:**
# - Cada ilha abriga sobretudo uma ou duas espécies dominantes (por ex. Biscoe → Gentoo e Adelie).
# - Ilha é variável geográfica que pode ajudar na classificação, pois funciona como proxy de espécie.

# %%
## 2. Preparação dos Dados

### 2.1. Tratamento de valores nulos

# %%
# Verificar nulos originais
print(df.isnull().sum())

# Preencher:
# - Numéricos: mediana
# - Categóricos: moda
df['bill_length_mm'].fillna(df['bill_length_mm'].median(), inplace=True)
df['bill_depth_mm'].fillna( df['bill_depth_mm'].median(),  inplace=True)
df['flipper_length_mm'].fillna(df['flipper_length_mm'].median(), inplace=True)
df['body_mass_g'].fillna(df['body_mass_g'].median(), inplace=True)
df['sex'].fillna(df['sex'].mode()[0], inplace=True)
df.isnull().sum()  # conferir novamente
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64
# <ipython-input-7-0e6cdde84502>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bill_length_mm'].fillna(df['bill_length_mm'].median(), inplace=True)
# <ipython-input-7-0e6cdde84502>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ### 2.2. Codificação de variáveis categóricas
#
# Embora árvores de decisão não necessitem de codificação, o Scikit‑Learn exige inputs numéricos.
# - Variáveis **nominais**: `species` (resposta), `island`, `sex`.

# %%
le_species = LabelEncoder()
le_island  = LabelEncoder()
le_sex     = LabelEncoder()

# Aqui criamos _nom apenas para as preditoras; species será o y.
df['island_nom'] = le_island.fit_transform(df['island'])
df['sex_nom']    = le_sex.fit_transform(df['sex'])

# %% [markdown]
# ### 2.3. Limpeza final
#
# Descartar colunas originais categóricas e manter a resposta (`species`) em primeiro lugar.

# %%
df_model = df[[
    'species',
    'bill_length_mm','bill_depth_mm','flipper_length_mm',
    'island_nom','sex_nom'
]]
df_model.head()
# Out:
#   species  bill_length_mm  bill_depth_mm  flipper_length_mm  island_nom  \
# 0  Adelie           39.10           18.7              181.0           2
# 1  Adelie           39.50           17.4              186.0           2
# 2  Adelie           40.30           18.0              195.0           2
# 3  Adelie           44.45           17.3              197.0           2
# 4  Adelie           36.70           19.3              193.0           2
#
#    sex_nom
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0

# %% [markdown]
# ### 2.4. Separação em treino e teste
#
# Proporção: **2/3** treino e **1/3** teste.

# %%
X = df_model.drop('species', axis=1)
y = le_species.fit_transform(df_model['species'])  # transformamos species para 0,1,2

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=1/3, random_state=42, stratify=y
)

print("Treino:", X_train.shape, "Teste:", X_test.shape)
# Out:
# Treino: (229, 5) Teste: (115, 5)

# %% [markdown]
# ## 3. Modelagem
#
# ### 3.1. Treinamento da Árvore de Decisão

# %%
tree = DecisionTreeClassifier(random_state=42)
tree.fit(X_train, y_train)

# Desenhar a árvore
plt.figure(figsize=(12,8))
plot_tree(tree,
          feature_names=X.columns,
          class_names=le_species.classes_,
          filled=True, rounded=True, fontsize=8)
plt.show()

# Quantas folhas?
n_leaves = tree.get_n_leaves()
print(f"Número de folhas da árvore treinada: {n_leaves}")
# Out:
# Número de folhas da árvore treinada: 14

# %% [markdown]
# **Resposta:**
# - A árvore treinada possui **`{n_leaves}`** folhas.

# %%
### 3.2. Avaliação do modelo
# Matriz de Confusão
y_pred = tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=le_species.classes_)
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão")
plt.show()

# Acurácia
acc = accuracy_score(y_test, y_pred)
print(f"Acurácia no conjunto de teste: {acc*100:.2f}%")
# Out:
# Acurácia no conjunto de teste: 98.26%

# %% [markdown]
# **Comentário Matriz de Confusão:**
# - Diagonal principal dominante indica que a maioria das instâncias foi classificada corretamente.
# - Alguns erros ocorrem entre Adelie e Chinstrap (classes mais parecidas).
#
# **Comentário Acurácia:**
# - A curadoria de referência obteve ≈ 96%. Nesta execução, temos **`{acc*100:.2f}%`**, o que confirma excelente performance.

# %% [markdown]
# ## 4. Predição de um novo pinguim
#
# **Exemplo de usuário:**
# - Comprimento do bico: 38.2 mm
# - Profundidade do bico: 18.1 mm
# - Comprimento da nadadeira: 185.0 mm
# - Ilha: Biscoe
# - Sexo: Male
#
# > **Obs.:** ajuste a ordem das colunas conforme X_train.

# %%
novo = pd.DataFrame([{
    'bill_length_mm': 38.2,
    'bill_depth_mm': 18.1,
    'flipper_length_mm': 185.0,
    'island_nom': le_island.transform(['Biscoe'])[0],
    'sex_nom':    le_sex.transform(['Male'])[0],
}])

esp_pred = tree.predict(novo)[0]
print("Espécie predita:", le_species.inverse_transform([esp_pred])[0])
# Out:
# Espécie predita: Adelie

# %% [markdown]
# > **Referência:**
# > Neste exemplo, o modelo costuma prever **Adelie**, o que confirma a mesma referência do material de apoio.
